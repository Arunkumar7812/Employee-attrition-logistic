# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv(r"c:\Users\Arun kumar\Downloads\house_size_price.csv")
print(df.head())

# Step 3: Define variables
X = df[['size_m2']]  # feature matrix
y = df['price']      # target vector

# Step 4: Train Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Step 5: Get slope, intercept, and R²
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)

print(f"Intercept (b0): {intercept:.2f}")
print(f"Slope (b1): {slope:.2f}")
print(f"R² Score: {r2:.3f}")

# Step 6: Predict price for size_m2 = 120
size = 120
predicted_price = model.predict([[size]])[0]
print(f"Predicted price for {size} m²: ₹{predicted_price:,.2f}")

# Step 7: Plot regression line
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel('House Size (m²)')
plt.ylabel('Price (₹)')
plt.title('House Price vs Size (Linear Regression)')
plt.legend()
plt.show()
# Out:
#       size_m2          price
# 0  186.465316  599022.373692
# 1  211.140468  677753.447334
# 2  184.285509  619187.225271
# 3  134.481499  453492.200820
# 4   74.959290  249648.033801
# Intercept (b0): 50090.43
# Slope (b1): 2994.19
# R² Score: 0.987
# Predicted price for 120 m²: ₹409,393.71
# c:\Users\Arun kumar\anaconda3\envs\myenv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
