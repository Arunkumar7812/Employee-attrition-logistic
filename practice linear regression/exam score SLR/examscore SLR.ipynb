# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv(r"c:\Users\Arun kumar\Downloads\study_hours_score.csv")
print(df.head())
# Out:
#       hours      score
# 0  5.939322  79.188121
# 1  7.436704  87.279918
# 2  6.424870  91.372308
# 3  5.903949  78.448910
# 4  4.812893  71.569383

# %%
# Step 3: Define X and y
X = df[['hours']]   # 2D array for sklearn
y = df['score']

# %%
# Step 4: Fit the Linear Regression model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Step 5: Extract coefficients
intercept = model.intercept_
slope = model.coef_[0]
r2 = model.score(X, y)  # R² score

print(f"Intercept (b0): {intercept:.2f}")
print(f"Slope (b1): {slope:.2f}")
print(f"R² Score: {r2:.3f}")
# Out:
# Intercept (b0): 50.44
# Slope (b1): 4.95
# R² Score: 0.878

# %%
# Step 6: Predict score for 9 hours of study
hours = 9
predicted_score = model.predict([[hours]])[0]
print(f"Predicted Score for {hours} hours of study: {predicted_score:.2f}")
# Out:
# Predicted Score for 9 hours of study: 94.95
# c:\Users\Arun kumar\anaconda3\envs\myenv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Step 7: Visualize the regression line
plt.scatter(X, y, color='blue', label='Actual Scores')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.title('Exam Score vs Study Hours (Simple Linear Regression)')
plt.legend()
plt.show()
